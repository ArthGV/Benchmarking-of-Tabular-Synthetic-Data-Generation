# %%
import random

max_age = 90
colors = ['blue', 'green', 'brown']
genders = ['M', 'F']
names = [
    "Alice", "Bob", "Charlie", "Diana", "Eve", "Frank", "Grace", "Hannah", "Ivy", "Jack",
    "Kelly", "Liam", "Mona", "Nina", "Oliver", "Paul", "Quincy", "Rachel", "Sam", "Tina",
    "Ursula", "Victor", "Wendy", "Xander", "Yara", "Zane", "Aaron", "Bella", "Caleb", "Dylan",
    "Emma", "Felix", "Gina", "Henry", "Iris", "James", "Kara", "Leo", "Mason", "Nora",
    "Oscar", "Penny", "Quinn", "Reed", "Sophia", "Tom", "Uma", "Vera", "Will", "Ximena",
    "Yosef", "Zoe", "Amos", "Becky", "Cory", "Drew", "Ella", "Finley", "Grace", "Harper",
    "Ian", "Jade", "Kendall", "Lily", "Max", "Nina", "Olivia", "Parker", "Quinn", "Riley",
    "Sasha", "Travis", "Ulysses", "Vanessa", "Wyatt", "Xander", "Yasmin", "Zane", "Alexis",
    "Brianna", "Calvin", "Delilah", "Ethan", "Fiona", "Gavin", "Holly", "Isaac", "Jasmine",
    "Kyle", "Lena", "Mackenzie", "Nash", "Olivia", "Pete", "Quincy", "Raul", "Simon", "Tanya",
    "Uriel", "Vince", "Willow", "Xander", "Yasmine", "Zara", "Ashley", "Blake", "Catherine",
    "Dean", "Eva", "Faith", "George", "Hannah", "Ian", "Jackie", "Kyle", "Lena", "Mason",
    "Nadia", "Owen", "Paulina", "Quincy", "Rebecca", "Sean", "Trina", "Ursula", "Veronica",
    "Walter", "Xander", "Yasmin", "Zeke", "Amber", "Bennett", "Claire", "Derek", "Ellie",
    "Francis", "Gabe", "Helen", "Ivana", "Joseph", "Kendra", "Lynn", "Maya", "Nathan",
    "Oscar", "Peter", "Quinn", "Rochelle", "Samuel", "Tori", "Ursula", "Vincent", "Wyatt",
    "Xander", "Yara", "Zoe", "Aaron", "Beth", "Charlie", "Diana", "Ethan", "Felix", "Gina"
]
cities = [
    "New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio", "San Diego", "Dallas", "San Jose",
    "Austin", "Jacksonville", "Fort Worth", "Columbus", "San Francisco", "Charlotte", "Indianapolis", "Seattle", "Denver", "Washington",
    "Boston", "El Paso", "Detroit", "Nashville", "Portland", "Memphis", "Oklahoma City", "Las Vegas", "Louisville", "Baltimore",
    "Milwaukee", "Albuquerque", "Tucson", "Fresno", "Sacramento", "Kansas City", "Long Beach", "Mesa", "Atlanta", "Colorado Springs",
    "Raleigh", "Miami", "Omaha", "Oakland", "Minneapolis", "Tulsa", "Bakersfield", "Wichita", "Arlington", "New Orleans",
    "Cleveland", "Tampa", "Bakersfield", "Honolulu", "Anaheim", "Aurora", "Santa Ana", "St. Louis", "Riverside", "Corpus Christi",
    "Pittsburgh", "Lexington", "Stockton", "Cincinnati", "St. Paul", "Toledo", "Newark", "Greensboro", "Buffalo", "Plano",
    "Henderson", "Fort Wayne", "Jersey City", "Chula Vista", "Durham", "Madison", "Lubbock", "Chandler", "Glendale", "Norfolk",
    "Gilbert", "Winston-Salem", "Reno", "Baton Rouge", "Anchorage", "Chesapeake", "Garland", "Irving", "Scottsdale", "North Las Vegas",
    "Fremont", "Boise", "Richmond", "San Bernardino", "Spokane", "Des Moines", "Modesto", "Moreno Valley", "Birmingham", "Tacoma",
    "Fontana", "Santa Clarita", "Birmingham", "Oxnard", "Huntington Beach", "Salt Lake City", "Grand Rapids", "Amarillo", "Glendale",
    "Columbia", "Peoria", "Knoxville", "Shreveport", "Jackson", "Fort Lauderdale", "Mobile", "Little Rock", "Mobile", "Huntsville",
    "Montgomery", "Columbus", "Grand Prairie", "Cape Coral", "Peoria", "Sioux Falls", "Springfield", "Laredo", "Cedar Rapids", "Lakewood",
    "Elk Grove", "St. Petersburg", "Chattanooga", "Vancouver", "Surprise", "Athens", "Lafayette", "Evansville", "Independence", "Lakewood",
    "Lancaster", "Provo", "Midland", "Newport News", "Denton", "Richardson", "Visalia", "Inglewood", "West Valley City", "North Charleston",
    "Carrollton", "Burbank", "Pompano Beach", "Green Bay", "Hickory", "Shreveport", "O'Fallon", "Bismarck", "Ames", "Elgin"
]

# %%
for _ in range(50000):
    age = int(random.random() * max_age)
    name = int(random.random() * max_age)
    color = int(random.random() * max_age)
    gender = int(random.random() * max_age)
    city = int(random.random() * max_age)
    print(f'{age},{color},{name},{gender},{city}')
# Out:
# 23,33,78,76,49
# 49,22,36,73,37
# 77,82,38,30,5
# 65,79,42,70,11
# 51,27,20,15,17
# 81,53,32,61,60
# 66,3,55,83,13
# 13,14,52,31,33
# 78,27,69,33,6
# 22,32,14,57,85
# 61,39,4,76,86
# 87,28,34,62,54
# 85,22,65,80,51
# 50,57,34,42,31
# 9,67,37,28,8
# 6,57,28,68,23
# 35,65,1,27,52
# 30,35,16,65,39
# 7,41,7,1,32
# 26,26,22,71,17
# 9,66,84,32,31
# 53,50,17,40,10
# 30,12,34,1,58
# 29,26,48,38,84
# 27,16,80,63,10
# 9,16,46,63,89
# 78,63,48,1,20
# 19,44,56,25,18
# 19,37,57,54,45
# 31,43,82,39,40
# 59,25,18,60,36
# 15,30,76,7,20
# 73,74,54,38,80
# 10,53,36,81,84
# 61,16,65,63,29
# 43,53,88,61,50
# 2,47,35,58,24
# 2,49,81,43,34
# 89,19,58,27,72
# 11,50,88,66,51
# 1,43,26,87,0
# 4,45,59,6,9
# 61,22,80,23,3
# 69,11,58,42,85
# 78,7,81,82,40
# 33,29,82,88,83
# 47,73,68,38,40
# 27,31,16,64,41
# 82,52,9,73,43
# 0,64,6,41,36
# 74,61,12,58,74
# 63,63,11,26,10
# 16,49,50,4,62
# 86,84,69,85,64
# 46,13,80,89,20
# 30,39,21,14,51
# 18,59,47,51,3
# 6,34,34,50,48
# 60,69,1,17,22
# 63,43,38,72,39
# ...
