# %%
import numpy as np
from sklearn.metrics import auc
y = np.array([1, 1, 2, 2])
pred = np.array([0.1, 0.4, 0.35, 0.8])
fpr, tpr, thresholds = roc_curve(y, pred, pos_label=2)
auc(fpr, tpr)
# Out:
# 0.75

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z)) -0.5

x = np.array([0,10,100,1000])
y = np.array([1,1,1,1])
h1 = x[-1] - x[-2]
h2 = x[-2] - x[-3]
second_derivative = 2 * ( (y[-1] - y[-2]) / h1 - (y[-2] - y[-3]) / h2 ) / (h1 + h2)
first_derivative = (y[-1] - y[-2]) / h1
print(first_derivative, second_derivative)
print ((np.tanh(first_derivative - 1) + 1) / 2, (np.tanh(second_derivative - 1) + 1) / 2)
print(((np.tanh(first_derivative - 1) + 1) / 2 + (np.tanh(second_derivative - 1) + 1) / 2) / 2)
# Out:
# 0.0 0.0
# 0.11920292202211757 0.11920292202211757
# 0.11920292202211757

# %%
np.exp(10)
# Out:
# 22026.465794806718

# %%
arr = np.array([0,0.1,0.5])
x = 0.9

idx = arr.shape[0] - np.searchsorted(arr, x, side='right')
chr(ord('A') + idx)
# Out:
# 'A'

# %%
from abc import ABC, abstractmethod
import numpy as np
from sklearn.metrics import auc

class BenchmarkMetric(ABC):

    @abstractmethod
    def compute_metric(self):
        pass

    @abstractmethod
    def compute_rank(self):
        pass

class AUCMetric(BenchmarkMetric):

    def __init__(self, rank_range: list[float]):
        self.rank_range = rank_range

    def compute_metric(self, data: list[float | int]):
        data = np.array(data)
        auc_score = auc(fpr, tpr)
        return auc_score
        
    def compute_rank(self, metric: float):
        idx = np.searchsorted(arr, x, side='right') - 1
        rank = chr(ord('A') + idx)
        return idx

# %%
R = []
m1 = [1,2,3]
m2 = [4,5,6]
R.append({
        'm1': m1,
        'm2': m2
    })
R
# Out:
# [{'m1': [1, 2, 3], 'm2': [4, 5, 6]}]

# %%
for i in range(len(N)):
    M_0, S_0, M_1,S_1 = self.fct()
